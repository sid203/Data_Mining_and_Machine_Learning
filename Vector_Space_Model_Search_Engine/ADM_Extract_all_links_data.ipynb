# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import sys

#Crawl for Cuisines
home_link='http://www.bbc.co.uk'
start_link="http://www.bbc.co.uk/food/recipes"
#Extracting the data from the webpages

def extract_method(rsoup):
    z_tmp=rsoup.find_all('p',{'class':'recipe-method__list-item-text'})
    txt=[]
    for i in z_tmp:
        txt.append(i)
        
    method_info=''
    for tag in txt:
        b=BeautifulSoup(str(tag))
        try:
            method_info=method_info+(b.find('p').contents[0])
        except:
            pass
        
        
    return ' '.join(method_info.split())


def extract_author(rsoup):
    result = ''
    for tag in rsoup.find_all(itemprop='author'):
        result = tag.contents[0]
    return result


def extract_cooking_time(rsoup):
    result = ''
    for tag in rsoup.find_all(itemprop='cookTime'):
        result = tag.contents[0]
    return result


def extract_dietary_information(rsoup):
    s="Vegetarian"
    items = rsoup.find_all("div", {"class":"recipe-metadata__dietary"})
    if bool(items)==True:
        for i in items:
            x = i.find("p", {"class": "recipe-metadata__dietary-vegetarian-text"}).get_text()
            if s in x:
                return(s)      
        
    else:
        return("No information")
    
def extract_ingredients(rsoup):
    
    items = rsoup.find_all("ul", {"class":"recipe-ingredients__list"})
    ingredients_info=''
    if bool(items)==True:
        for i in items:
            x = i.find_all("li", {"class": "recipe-ingredients__list-item"})
            for j in x:
                ingredients_info+=(j.get_text())
                
    else:
        return ('No Information')

    return ' '.join(ingredients_info.split())

    
def extract_prep_time(rsoup):
    result = ''
    for tag in rsoup.find_all(itemprop='prepTime'):
        result = tag.contents[0]
    return result


def extract_program_information(rsoup):
    
    items = rsoup.find_all("div", {"class":"recipe-is-from-widget__about"})
    if bool(items)==True:
        for i in items:
            x = i.find("p", {"class": "recipe-is-from-widget__programme-series-title"}).get_text()
            return(x.strip())
        
    else:
        return("No information")

def extract_serves(rsoup):
    result = ''
    for tag in rsoup.find_all(itemprop='recipeYield'):
        result = tag.contents[0]
    return result

def extract_title(rsoup):
    result = ''
    for tag in rsoup.find_all(itemprop='name'):
        result = tag.contents[0]
    return result

#File management functions

def collect_all_information(url):
    ## Use the Functions to get the Data #
    try:
        recipe=requests.get(url)
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        print(e)
        sys.exit(1)
    rsoup = BeautifulSoup(recipe.text, "lxml")

    Single_Recipe_Data=[]
    auth=extract_author(rsoup)
    p_time=extract_prep_time(rsoup)
    c_time=extract_cooking_time(rsoup)
    sv=extract_serves(rsoup)
    dietary=extract_dietary_information(rsoup)
    progrm=extract_program_information(rsoup)
    ing=extract_ingredients(rsoup)
    m=extract_method(rsoup)
    t=extract_title(rsoup)
    # Save the Data together in one, Variable , and return that Variable
    Single_Recipe_Data.append(t)
    Single_Recipe_Data.append(auth)
    Single_Recipe_Data.append(p_time)
    Single_Recipe_Data.append(c_time)
    Single_Recipe_Data.append(dietary)
    Single_Recipe_Data.append(progrm)
    Single_Recipe_Data.append(sv)
    Single_Recipe_Data.append(ing)
    Single_Recipe_Data.append(m)
    
    return Single_Recipe_Data

def write_to_file(Recipe,file_name):
    target=open(file_name,'a',encoding='utf-8')
    for element in Recipe:
        target.write(str(element))
        target.write('\n')
    target.close()
    

def read_all_links(file_name):

    target=open(file_name, 'r',encoding='utf-8')
    links=[wrd.strip() for wrd in target]

    target.close()
    return links


def extract_all_information(batch,c):
    #d=make_batches('all_recipe_links.txt')
    path = './ADM_dataset/test/___'
    #c=0
    #dt=0
    #for batch in d:
    #    print('Batch num'+str(dt)+'starting.....')
    for link in batch:
        print(link)
        print('\n')
        print(c)
        single_recipe=collect_all_information(link)
        write_to_file(single_recipe,path+str(c)+'.txt')
        time.sleep(1)
        c=c+1
        #print('Batch num '+str(dt)+'complete !!')
        #dt=dt+1
    return 'done'

def make_batches(file_name_links,n=1000):
    l = read_all_links(file_name_links)
    k=[l[i:i + n] for i in range(0, len(l), n)]
    return k

# %%
d=make_batches('all_recipe_links.txt')

# %%
a=extract_all_information(d[11],11000)
# Out:
# http://www.bbc.co.uk/food/recipes/steak_with_bernaise_14402
#
#
# 11000
# /home/siddhant/python/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/siddhant/python/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# http://www.bbc.co.uk/food/recipes/asianstyletofustirfr_92503
#
#
# 11001
# http://www.bbc.co.uk/food/recipes/oven-cooked_chicken_04728
#
#
# 11002
# http://www.bbc.co.uk/food/recipes/eccles_cakes_72475
#
#
# 11003
# http://www.bbc.co.uk/food/recipes/chocolatehazelnutmou_88907
#
#
# 11004
# http://www.bbc.co.uk/food/recipes/scallops_with_78274
#
#
# 11005
# http://www.bbc.co.uk/food/recipes/smoked_tea_duck_with_03414
#
#
# 11006
# http://www.bbc.co.uk/food/recipes/grapefruit_and_ginger_59169
#
#
# 11007
# http://www.bbc.co.uk/food/recipes/mozzarellacrustbeeff_80165
#
#
# 11008
# http://www.bbc.co.uk/food/recipes/parsnipsoupwithsteam_93513
#
#
# 11009
# http://www.bbc.co.uk/food/recipes/passionfruitsouffles_88944
#
#
# 11010
# http://www.bbc.co.uk/food/recipes/bread_and_butter_pudding_72702
#
#
# 11011
# http://www.bbc.co.uk/food/recipes/cheeseandpotatocakes_85966
#
#
# 11012
# http://www.bbc.co.uk/food/recipes/surfandturf_90690
#
#
# 11013
# http://www.bbc.co.uk/food/recipes/cheese_chive_and_mustard_48610
#
#
# 11014
# http://www.bbc.co.uk/food/recipes/mangohedgehog_90729
#
#
# 11015
# http://www.bbc.co.uk/food/recipes/chocolatehazelnutpud_76334
#
#
# 11016
# http://www.bbc.co.uk/food/recipes/applebaconandblackpu_70513
#
#
# 11017
# http://www.bbc.co.uk/food/recipes/jamaicangingergateau_85268
#
#
# 11018
# http://www.bbc.co.uk/food/recipes/whitesauce_1298
#
#
# 11019
# http://www.bbc.co.uk/food/recipes/marias_fideu_61565
#
#
# 11020
# http://www.bbc.co.uk/food/recipes/braisedlambshankswit_88343
#
#
# 11021
# http://www.bbc.co.uk/food/recipes/turbotwithrazorclams_89698
#
#
# 11022
# http://www.bbc.co.uk/food/recipes/bruschettawithchicke_66105
#
#
# 11023
# http://www.bbc.co.uk/food/recipes/sage_and_onion_tear_and_81823
#
#
# 11024
# http://www.bbc.co.uk/food/recipes/breastoflambwithtart_79286
#
#
# 11025
# http://www.bbc.co.uk/food/recipes/nectar_cake_with_hidden_06597
#
#
# 11026
# http://www.bbc.co.uk/food/recipes/red_fruit_tarts_and_29983
#
#
# 11027
# http://www.bbc.co.uk/food/recipes/toms_fried_chicken_in_a_83178
#
#
# 11028
# http://www.bbc.co.uk/food/recipes/peanut_butter_chicken_63146
#
#
# 11029
# http://www.bbc.co.uk/food/recipes/haddockcevichewithcr_92452
#
#
# 11030
# http://www.bbc.co.uk/food/recipes/figanddatescones_66042
#
#
# 11031
# http://www.bbc.co.uk/food/recipes/grilled_pork_chop_with_58226
#
#
# 11032
# http://www.bbc.co.uk/food/recipes/freshspaghettiwithto_84970
#
#
# 11033
# http://www.bbc.co.uk/food/recipes/chicken_pot_pie_with_52117
#
#
# 11034
# http://www.bbc.co.uk/food/recipes/cream_of_celeriac_soup_59784
#
#
# 11035
# http://www.bbc.co.uk/food/recipes/sussex_pond_pudding_with_23049
#
#
# 11036
# http://www.bbc.co.uk/food/recipes/freshpeaandspinachso_88584
#
#
# 11037
# http://www.bbc.co.uk/food/recipes/brandy_snaps_47363
#
#
# 11038
# http://www.bbc.co.uk/food/recipes/treacle_tart_36254
#
#
# 11039
# http://www.bbc.co.uk/food/recipes/asianbroth_76488
#
#
# 11040
# http://www.bbc.co.uk/food/recipes/chocolatecookieicecr_88723
#
#
# 11041
# http://www.bbc.co.uk/food/recipes/chocolate_cookies_with_95245
#
#
# 11042
# http://www.bbc.co.uk/food/recipes/slow_roasted_lamb_35292
#
#
# 11043
# http://www.bbc.co.uk/food/recipes/seabreammarinatedinr_87263
#
#
# 11044
# http://www.bbc.co.uk/food/recipes/dover_sole_and_08196
#
#
# 11045
# http://www.bbc.co.uk/food/recipes/carrotcakewithcreamc_86392
#
#
# 11046
# http://www.bbc.co.uk/food/recipes/searedbeefsaladwithc_70260
#
#
# 11047
# http://www.bbc.co.uk/food/recipes/classicmargarita_84327
#
#
# 11048
# http://www.bbc.co.uk/food/recipes/rockyroadcrunchbars_87104
#
#
# 11049
# http://www.bbc.co.uk/food/recipes/millefellewithicecre_76916
#
#
# 11050
# http://www.bbc.co.uk/food/recipes/spinach_and_shrimp_23513
#
#
# 11051
# http://www.bbc.co.uk/food/recipes/cheesesoufflebuckwhe_93524
#
#
# 11052
# http://www.bbc.co.uk/food/recipes/pad_thai_salad_01326
#
#
# 11053
# http://www.bbc.co.uk/food/recipes/japanesevegetablesti_92442
#
#
# 11054
# http://www.bbc.co.uk/food/recipes/bangbangchicken_82544
#
#
# 11055
# http://www.bbc.co.uk/food/recipes/bakedtomatoandcheese_86037
#
#
# 11056
# http://www.bbc.co.uk/food/recipes/goats_cheese_butternut_19608
#
#
# 11057
# http://www.bbc.co.uk/food/recipes/roastduckbreastwithc_72370
#
#
# 11058
# http://www.bbc.co.uk/food/recipes/pork_beans_and_kimchi_91059
#
#
# 11059
# http://www.bbc.co.uk/food/recipes/clearnoodlesoupwithr_92379
#
#
# 11060
# http://www.bbc.co.uk/food/recipes/the_perfect_chefs_rump_23034
#
#
# 11061
# http://www.bbc.co.uk/food/recipes/roast_chicken_with_54406
#
#
# 11062
# http://www.bbc.co.uk/food/recipes/marinatedbeefwithegg_84981
#
#
# 11063
# http://www.bbc.co.uk/food/recipes/grilledsesameprawnsw_88888
#
#
# 11064
# http://www.bbc.co.uk/food/recipes/kipperfishcakeswitht_92672
#
#
# 11065
# http://www.bbc.co.uk/food/recipes/sconeswithmarronsgla_87409
#
#
# 11066
# http://www.bbc.co.uk/food/recipes/chocolateandmacadami_83825
#
#
# 11067
# http://www.bbc.co.uk/food/recipes/chickenteriyakiwithb_78211
#
#
# 11068
# http://www.bbc.co.uk/food/recipes/roasted_breast_of_46928
#
#
# 11069
# http://www.bbc.co.uk/food/recipes/wensleydaleapplepie_83718
#
#
# 11070
# http://www.bbc.co.uk/food/recipes/dauphinoisepotatoes_90205
#
#
# 11071
# http://www.bbc.co.uk/food/recipes/chickenandmushroompi_89034
#
#
# 11072
# http://www.bbc.co.uk/food/recipes/asiannoodlesoup_81146
#
#
# 11073
# http://www.bbc.co.uk/food/recipes/crispy_duck_salad_03934
#
#
# 11074
# http://www.bbc.co.uk/food/recipes/turbot_steaks_with_cream_43727
#
#
# 11075
# http://www.bbc.co.uk/food/recipes/quickchickenliverpat_71660
#
#
# 11076
# http://www.bbc.co.uk/food/recipes/poachedcornfedchicke_90894
#
#
# 11077
# http://www.bbc.co.uk/food/recipes/victorias_crown_99544
#
#
# 11078
# http://www.bbc.co.uk/food/recipes/sweetandspicyduckwit_87237
#
#
# 11079
# http://www.bbc.co.uk/food/recipes/spicedpumpkintartwit_84324
#
#
# 11080
# http://www.bbc.co.uk/food/recipes/tamarind-marinated_90215
#
#
# 11081
# http://www.bbc.co.uk/food/recipes/roast_loin_of_venison_93075
#
#
# 11082
# http://www.bbc.co.uk/food/recipes/raspberry_swiss_roll_08757
#
#
# 11083
# http://www.bbc.co.uk/food/recipes/rhubarb_and_ginger_78424
#
#
# 11084
# http://www.bbc.co.uk/food/recipes/skatewithaniseedliqu_90438
#
#
# 11085
# http://www.bbc.co.uk/food/recipes/flatbreads_00946
#
#
# 11086
# http://www.bbc.co.uk/food/recipes/barnsley_chops_with_60141
#
#
# 11087
# http://www.bbc.co.uk/food/recipes/richchristmaspudding_8935
#
#
# 11088
# http://www.bbc.co.uk/food/recipes/smoked_roasted_loin_of_46952
#
#
# 11089
# http://www.bbc.co.uk/food/recipes/indianstylefishcurry_92835
#
#
# 11090
# http://www.bbc.co.uk/food/recipes/stuffedbakedbananas_89129
#
#
# 11091
# http://www.bbc.co.uk/food/recipes/chocolateandorangeso_88280
#
#
# 11092
# http://www.bbc.co.uk/food/recipes/clearmushroombrothwi_86857
#
#
# 11093
# http://www.bbc.co.uk/food/recipes/braised_hogget_pie_16464
#
#
# 11094
# http://www.bbc.co.uk/food/recipes/chocolate_espresso_cake_56805
#
#
# 11095
# http://www.bbc.co.uk/food/recipes/chocolate_buttercream_11918
#
#
# 11096
# http://www.bbc.co.uk/food/recipes/mokatines_96500
#
#
# 11097
# http://www.bbc.co.uk/food/recipes/wintercobbler_90041
#
#
# 11098
# http://www.bbc.co.uk/food/recipes/chargrilledpearswith_79476
#
#
# 11099
# http://www.bbc.co.uk/food/recipes/sweetcornrisottowith_87160
#
#
# 11100
# http://www.bbc.co.uk/food/recipes/burrata_filled_59791
#
#
# 11101
# http://www.bbc.co.uk/food/recipes/easy_creamy_vanilla_20376
#
#
# 11102
# http://www.bbc.co.uk/food/recipes/guavakulfiwithtropic_86120
#
#
# 11103
# http://www.bbc.co.uk/food/recipes/figgy_dowdy_pudding_with_81941
#
#
# 11104
# http://www.bbc.co.uk/food/recipes/crispfriedmonkfishwi_88087
#
#
# 11105
# http://www.bbc.co.uk/food/recipes/cornmealflatbreads_86122
#
#
# 11106
# http://www.bbc.co.uk/food/recipes/bacon_strata_83356
#
#
# 11107
# http://www.bbc.co.uk/food/recipes/deepfriedfishinbeerb_67776
#
#
# 11108
# http://www.bbc.co.uk/food/recipes/lemon_and_thyme_pork_15402
#
#
# 11109
# http://www.bbc.co.uk/food/recipes/tuscanbeansoup_82379
#
#
# 11110
# http://www.bbc.co.uk/food/recipes/colcannon_13802
#
#
# 11111
# http://www.bbc.co.uk/food/recipes/pepperedsirloinsteak_79508
#
#
# 11112
# http://www.bbc.co.uk/food/recipes/beef_and_ale_stew_76412
#
#
# 11113
# http://www.bbc.co.uk/food/recipes/fastrhubarbtartwithm_92278
#
#
# 11114
# http://www.bbc.co.uk/food/recipes/baked_apples_in_a_74612
#
#
# 11115
# http://www.bbc.co.uk/food/recipes/roast_marinated_pork_55410
#
#
# 11116
# http://www.bbc.co.uk/food/recipes/sweetraguwithcoriand_87299
#
#
# 11117
# http://www.bbc.co.uk/food/recipes/venisonchilli_86999
#
#
# 11118
# http://www.bbc.co.uk/food/recipes/griddledfennelwithah_89415
#
#
# 11119
# http://www.bbc.co.uk/food/recipes/chocolate_fondant_with_29611
#
#
# 11120
# http://www.bbc.co.uk/food/recipes/minifryup_90126
#
#
# 11121
# http://www.bbc.co.uk/food/recipes/hotsalmonwithlimechi_93821
#
#
# 11122
# http://www.bbc.co.uk/food/recipes/how_to_make_chilli_11991
#
#
# 11123
# http://www.bbc.co.uk/food/recipes/mapleroastparsnips_84758
#
#
# 11124
# http://www.bbc.co.uk/food/recipes/cinnamonandappleturn_84027
#
#
# 11125
# http://www.bbc.co.uk/food/recipes/saladofspinachrarero_90094
#
#
# 11126
# http://www.bbc.co.uk/food/recipes/butternutsquashandpu_84333
#
#
# 11127
# http://www.bbc.co.uk/food/recipes/soffritto_82365
#
#
# 11128
# http://www.bbc.co.uk/food/recipes/mayorchidsweetandsou_11032
#
#
# 11129
# http://www.bbc.co.uk/food/recipes/duckandwenslydaledum_78889
#
#
# 11130
# http://www.bbc.co.uk/food/recipes/tomatoandredpepperso_10654
#
#
# 11131
# http://www.bbc.co.uk/food/recipes/peachesinsauternes_91630
#
#
# 11132
# http://www.bbc.co.uk/food/recipes/braised_rabbit_with_63312
#
#
# 11133
# http://www.bbc.co.uk/food/recipes/peapuree_81037
#
#
# 11134
# http://www.bbc.co.uk/food/recipes/asiannoodlesalad_82661
#
#
# 11135
# http://www.bbc.co.uk/food/recipes/beef_fillet_with_potato_43905
#
#
# 11136
# http://www.bbc.co.uk/food/recipes/caramelisedsatsumasw_88935
#
#
# 11137
# http://www.bbc.co.uk/food/recipes/how_to_make_preserved_01545
#
#
# 11138
# http://www.bbc.co.uk/food/recipes/herbcrustedsalmonwit_84490
#
#
# 11139
# http://www.bbc.co.uk/food/recipes/shrimpravioliwithshr_85426
#
#
# 11140
# http://www.bbc.co.uk/food/recipes/penne_with_sausage_26109
#
#
# 11141
# http://www.bbc.co.uk/food/recipes/cardamomkulfi_74037
#
#
# 11142
# http://www.bbc.co.uk/food/recipes/spicykoftasonherbsal_88918
#
#
# 11143
# http://www.bbc.co.uk/food/recipes/make-ahead_red_cabbage_13106
#
#
# 11144
# http://www.bbc.co.uk/food/recipes/walnut_and_stilton_soda_33324
#
#
# 11145
# http://www.bbc.co.uk/food/recipes/grilledsquidwithlemo_70508
#
#
# 11146
# http://www.bbc.co.uk/food/recipes/pennealarrabiatapast_83813
#
#
# 11147
# http://www.bbc.co.uk/food/recipes/chillipolentacoatedc_84426
#
#
# 11148
# http://www.bbc.co.uk/food/recipes/snow_eggs_oeufs__la_01202
#
#
# 11149
# http://www.bbc.co.uk/food/recipes/povitica_92623
#
#
# 11150
# http://www.bbc.co.uk/food/recipes/celeriac_and_carrot_soup_85608
#
#
# 11151
# http://www.bbc.co.uk/food/recipes/raised_game_pie_90104
#
#
# 11152
# http://www.bbc.co.uk/food/recipes/beefoysterandalepie_92453
#
#
# 11153
# http://www.bbc.co.uk/food/recipes/bloodymary_84135
#
#
# 11154
# http://www.bbc.co.uk/food/recipes/panfriedsnapperwithb_12160
#
#
# 11155
# http://www.bbc.co.uk/food/recipes/orangesouffle_89078
#
#
# 11156
# http://www.bbc.co.uk/food/recipes/passionfruitcheeseca_85291
#
#
# 11157
# http://www.bbc.co.uk/food/recipes/portstirfrywithpearc_79989
#
#
# 11158
# http://www.bbc.co.uk/food/recipes/beef_cobbler_with_79871
#
#
# 11159
# http://www.bbc.co.uk/food/recipes/quick_cheats_pizza_88026
#
#
# 11160
# http://www.bbc.co.uk/food/recipes/panhaggerty_93163
#
#
# 11161
# http://www.bbc.co.uk/food/recipes/raspberrymousse_89893
#
#
# 11162
# http://www.bbc.co.uk/food/recipes/brandy_snaps_17321
#
#
# 11163
# http://www.bbc.co.uk/food/recipes/fennelsausagesbraise_86774
#
#
# 11164
# http://www.bbc.co.uk/food/recipes/filletoflambmarinate_92826
#
#
# 11165
# http://www.bbc.co.uk/food/recipes/chocolate_salame_17894
#
#
# 11166
# http://www.bbc.co.uk/food/recipes/chocolate_cardamom_and_62885
#
#
# 11167
# http://www.bbc.co.uk/food/recipes/rag_alla_napoletana_76351
#
#
# 11168
# http://www.bbc.co.uk/food/recipes/chicken_and_rosewater_70042
#
#
# 11169
# http://www.bbc.co.uk/food/recipes/tomatobasilandoliveb_85075
#
#
# 11170
# http://www.bbc.co.uk/food/recipes/warm_spiced_cauliflower_36652
#
#
# 11171
# http://www.bbc.co.uk/food/recipes/panfriedfilletsofsea_91705
#
#
# 11172
# http://www.bbc.co.uk/food/recipes/pork_with_dried_fruit_53663
#
#
# 11173
# http://www.bbc.co.uk/food/recipes/grilledbeefrumpsteak_84729
#
#
# 11174
# http://www.bbc.co.uk/food/recipes/apricotbriochetart_70816
#
#
# 11175
# http://www.bbc.co.uk/food/recipes/warmlambsalad_84697
#
#
# 11176
# http://www.bbc.co.uk/food/recipes/microwave_spaghetti_44920
#
#
# 11177
# http://www.bbc.co.uk/food/recipes/sultana_scones_with_98294
#
#
# 11178
# http://www.bbc.co.uk/food/recipes/pecan_toffee_cheesecake_22876
#
#
# 11179
# http://www.bbc.co.uk/food/recipes/saddle_of_lamb_with_herb_91234
#
#
# 11180
# http://www.bbc.co.uk/food/recipes/creamy_white_wine_58519
#
#
# 11181
# http://www.bbc.co.uk/food/recipes/eggybread_76849
#
#
# 11182
# http://www.bbc.co.uk/food/recipes/manhattan_87544
#
#
# 11183
# http://www.bbc.co.uk/food/recipes/marinated_beef_with_91515
#
#
# 11184
# http://www.bbc.co.uk/food/recipes/parseefishinbananale_90849
#
#
# 11185
# http://www.bbc.co.uk/food/recipes/egg_tomato_fried_bread_45770
#
#
# 11186
# http://www.bbc.co.uk/food/recipes/pauls_chocolate_clairs_59944
#
#
# 11187
# http://www.bbc.co.uk/food/recipes/ginger_scallops_with_31234
#
#
# 11188
# http://www.bbc.co.uk/food/recipes/chocolate_pot_with_54547
#
#
# 11189
# http://www.bbc.co.uk/food/recipes/roastedmapleorangesw_88543
#
#
# 11190
# http://www.bbc.co.uk/food/recipes/shredded_duck_with_plums_60349
#
#
# 11191
# http://www.bbc.co.uk/food/recipes/fresh_pea_courgette_and_97855
#
#
# 11192
# http://www.bbc.co.uk/food/recipes/salmon_with_sauce_vert_07187
#
#
# 11193
# http://www.bbc.co.uk/food/recipes/cranberry_and_coconut_69378
#
#
# 11194
# http://www.bbc.co.uk/food/recipes/goatscheesewithchico_83705
#
#
# 11195
# http://www.bbc.co.uk/food/recipes/softpolentawithmushr_88002
#
#
# 11196
# http://www.bbc.co.uk/food/recipes/quickchickenmadras_67786
#
#
# 11197
# http://www.bbc.co.uk/food/recipes/gigotoflambwithrosem_6997
#
#
# 11198
# http://www.bbc.co.uk/food/recipes/roast_chicken_thigh_41789
#
#
# 11199
# http://www.bbc.co.uk/food/recipes/freshoysterswithsauc_10192
#
#
# 11200
# http://www.bbc.co.uk/food/recipes/irishstoutpunch_87001
#
#
# 11201
# http://www.bbc.co.uk/food/recipes/pan-fried_plaice_with_57647
#
#
# 11202
# http://www.bbc.co.uk/food/recipes/roastsweetpotatochil_89279
#
#
# 11203
# http://www.bbc.co.uk/food/recipes/classic_victoria_sponge_45518
#
#
# 11204
# http://www.bbc.co.uk/food/recipes/karara_aloo_chaat_crisp_45821
#
#
# 11205
# http://www.bbc.co.uk/food/recipes/hotbeefandbeanthread_67794
#
#
# 11206
# http://www.bbc.co.uk/food/recipes/honeycombfool_76811
#
#
# 11207
# http://www.bbc.co.uk/food/recipes/carrot_and_courgette_63594
#
#
# 11208
# http://www.bbc.co.uk/food/recipes/halloumiandmangowith_1048
#
#
# 11209
# http://www.bbc.co.uk/food/recipes/spaghettiwithcherryt_82393
#
#
# 11210
# http://www.bbc.co.uk/food/recipes/brambleandbutterscot_67688
#
#
# 11211
# http://www.bbc.co.uk/food/recipes/honeyorangesservedwi_76271
#
#
# 11212
# http://www.bbc.co.uk/food/recipes/white_radish_salad_90778
#
#
# 11213
# http://www.bbc.co.uk/food/recipes/griddledlambwitheggy_72110
#
#
# 11214
# http://www.bbc.co.uk/food/recipes/stickytoffeepuddingw_72993
#
#
# 11215
# http://www.bbc.co.uk/food/recipes/walnutandstiltoncros_88009
#
#
# 11216
# http://www.bbc.co.uk/food/recipes/classicchickencaesar_86187
#
#
# 11217
# http://www.bbc.co.uk/food/recipes/tomatorelish_81521
#
#
# 11218
# http://www.bbc.co.uk/food/recipes/chargrilledpearswith_79093
#
#
# 11219
# http://www.bbc.co.uk/food/recipes/classic_stem_ginger_83286
#
#
# 11220
# http://www.bbc.co.uk/food/recipes/cheeseonionandpotato_86543
#
#
# 11221
# http://www.bbc.co.uk/food/recipes/perfectroastpotatoes_13801
#
#
# 11222
# http://www.bbc.co.uk/food/recipes/mezze_platter_with_12562
#
#
# 11223
# http://www.bbc.co.uk/food/recipes/simplesimnelcake_71981
#
#
# 11224
# http://www.bbc.co.uk/food/recipes/mushroom_and_spinach_09065
#
#
# 11225
# http://www.bbc.co.uk/food/recipes/tomatochickenandpepp_85655
#
#
# 11226
# http://www.bbc.co.uk/food/recipes/spanish_garlic_prawns_89162
#
#
# 11227
# http://www.bbc.co.uk/food/recipes/venison_curry_28033
#
#
# 11228
# http://www.bbc.co.uk/food/recipes/whole_baked_seabass_with_36512
#
#
# 11229
# http://www.bbc.co.uk/food/recipes/chicken_with_harissa_29438
#
#
# 11230
# http://www.bbc.co.uk/food/recipes/passionfruittart_85085
#
#
# 11231
# http://www.bbc.co.uk/food/recipes/chorizopepperandcous_75307
#
#
# 11232
# http://www.bbc.co.uk/food/recipes/pauls_kransekake_83354
#
#
# 11233
# http://www.bbc.co.uk/food/recipes/warmgreeksaladwithpa_84442
#
#
# 11234
# http://www.bbc.co.uk/food/recipes/sausageandwensleydal_85704
#
#
# 11235
# http://www.bbc.co.uk/food/recipes/tomatoandbasiltart_72416
#
#
# 11236
# http://www.bbc.co.uk/food/recipes/chocolate_and_cardamom_49894
#
#
# 11237
# http://www.bbc.co.uk/food/recipes/oriental-style_marinated_79700
#
#
# 11238
# http://www.bbc.co.uk/food/recipes/microwave_jacket_34010
#
#
# 11239
# http://www.bbc.co.uk/food/recipes/chocolatepancakesouf_84244
#
#
# 11240
# http://www.bbc.co.uk/food/recipes/cranachan_cheesecake_54836
#
#
# 11241
# http://www.bbc.co.uk/food/recipes/broccoliandpotatosou_92460
#
#
# 11242
# http://www.bbc.co.uk/food/recipes/celeriac_and_apple_soup_32322
#
#
# 11243
# http://www.bbc.co.uk/food/recipes/poachedpearsinsauter_65555
#
#
# 11244
# http://www.bbc.co.uk/food/recipes/pearl_barley_butternut_61137
#
#
# 11245
# http://www.bbc.co.uk/food/recipes/bakedscallopswithsun_92468
#
#
# 11246
# http://www.bbc.co.uk/food/recipes/allinonewhitesauce_66114
#
#
# 11247
# http://www.bbc.co.uk/food/recipes/chorizo_and_tomato_soup_10248
#
#
# 11248
# http://www.bbc.co.uk/food/recipes/cheddarcheesesouffle_88285
#
#
# 11249
# http://www.bbc.co.uk/food/recipes/roastpheasantwithlem_90249
#
#
# 11250
# http://www.bbc.co.uk/food/recipes/gateaualacrme_93878
#
#
# 11251
# http://www.bbc.co.uk/food/recipes/ovenbakedgoatscheese_86203
#
#
# 11252
# http://www.bbc.co.uk/food/recipes/raspberry_cheesecake_04819
#
#
# 11253
# http://www.bbc.co.uk/food/recipes/stuffedchickenbreast_89240
#
#
# 11254
# http://www.bbc.co.uk/food/recipes/fish_cakes_with_tomato_22086
#
#
# 11255
# http://www.bbc.co.uk/food/recipes/oxtailsaladwithsumme_86396
#
#
# 11256
# http://www.bbc.co.uk/food/recipes/friedonionchorizoand_84497
#
#
# 11257
# http://www.bbc.co.uk/food/recipes/pork_loin_cooked_in_milk_84303
#
#
# 11258
# http://www.bbc.co.uk/food/recipes/rhubarb_and_custard_56928
#
#
# 11259
# http://www.bbc.co.uk/food/recipes/chocolate_amaretto_21084
#
#
# 11260
# http://www.bbc.co.uk/food/recipes/upsidedowncherrytoma_87767
#
#
# 11261
# http://www.bbc.co.uk/food/recipes/_fillet_of_beef_82682
#
#
# 11262
# http://www.bbc.co.uk/food/recipes/roastporkwithcarrots_91061
#
#
# 11263
# http://www.bbc.co.uk/food/recipes/linguinewithchillicr_7294
#
#
# 11264
# http://www.bbc.co.uk/food/recipes/rump_steak_with_sour_57511
#
#
# 11265
# http://www.bbc.co.uk/food/recipes/talegiofonduewithcia_78032
#
#
# 11266
# http://www.bbc.co.uk/food/recipes/stuffedporkbellywith_91404
#
#
# 11267
# http://www.bbc.co.uk/food/recipes/roquefort_and_walnut_16074
#
#
# 11268
