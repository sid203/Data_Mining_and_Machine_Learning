# %%
#Load Dataset 
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.snowball import EnglishStemmer
from nltk import word_tokenize
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import pprint as pp
import string
from sklearn.neighbors import KNeighborsClassifier



cachedStopWords = stopwords.words("english")
def testFuncNew(text):
        text = ' '.join([word for word in text.split() if word not in cachedStopWords])
        return text

############################################
stemmer = EnglishStemmer()

def stemming_tokenizer(text):
    #text =text.decode('utf-8')
    stop_words_removed_text = testFuncNew(text)
    stemmed_text = [stemmer.stem(word) for word in word_tokenize(stop_words_removed_text, language='english')]
    return stemmed_text


def stemming_tokenizer_no_stop_words(text):
    #text =text.decode('utf-8')
    stemmed_text = [stemmer.stem(word) for word in word_tokenize(text, language='english')]
    return stemmed_text
######################################################################




## Dataset containing Positive and neative sentences on Amazon products
data_folder_training_set = "./Positve_negative_sentences/Training"
data_folder_test_set     = "./Positve_negative_sentences/Test"

training_dataset = load_files(data_folder_training_set)
test_dataset = load_files(data_folder_test_set)
print()
print ("----------------------")
print((training_dataset.target_names))
print ("----------------------")
print()


# Load Training-Set
X_train, X_test_DUMMY_to_ignore, Y_train, Y_test_DUMMY_to_ignore = train_test_split(training_dataset.data,
                                                    training_dataset.target,
                                                    test_size=0.0)
target_names = training_dataset.target_names

# Load Test-Set
X_train_DUMMY_to_ignore, X_test, Y_train_DUMMY_to_ignore, Y_test = train_test_split(test_dataset.data,
                                                    test_dataset.target,
                                                    train_size=0.0)

target_names = training_dataset.target_names
print()
print("----------------------")
print ("Creating Training Set and Test Set")
print()
print ("Training Set Size")
print(Y_train.shape)
print()
print ("Test Set Size")
print(Y_test.shape)
print()
print("Classes:")
print(target_names)
print ("----------------------")
# Out:
# ----------------------
# []
# ----------------------
#
#
# ----------------------
# Creating Training Set and Test Set
#
# Training Set Size
# (0,)
#
# Test Set Size
# (0,)
#
# Classes:
# []
# ----------------------

# %%
training_dataset
# Out:
# {'DESCR': None,
#  'data': [],
#  'filenames': array([], dtype=float64),
#  'target': array([], dtype=float64),
#  'target_names': []}

# %%
## Vectorization object
vectorizer = TfidfVectorizer(strip_accents= None,preprocessor = None)

## classifier
nbc = KNeighborsClassifier()

pipeline = Pipeline([('vect',vectorizer),('nbc',nbc),])

parameters = {
    'vect__tokenizer': [stemming_tokenizer,stemming_tokenizer_no_stop_words],
    'vect__ngram_range': [(1, 1), (1, 2),(1,3)],
    'vect__use_idf':[True,False],
    'nbc__weights':['uniform','distance'],
    'nbc__algorithm':['auto']
    
    }

grid_search = GridSearchCV(pipeline,
                           parameters,
                           scoring=metrics.make_scorer(metrics.average_precision_score, average='weighted'),
                           cv=10,
                           n_jobs=-1,
                           verbose=10)

# %%
grid_fit=grid_search.fit(X_train, Y_train)
grid_fit.grid_scores_
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.885952, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.933571, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.885952, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.805952, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.3s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.955714, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.878214, total=   1.3s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.920833, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.930556, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.2s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.925606, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    7.0s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.966786, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.885952, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.977857, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   11.1s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.967273, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.944643, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.965278, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.879425, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.870945, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.865390, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.815714, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   14.8s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.883651, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.922500, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.900357, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.966786, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.921645, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.932987, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.851852, total=   1.6s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.872500, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.780994, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   21.3s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.784643, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.858797, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.889286, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.866350, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.934545, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False, score=0.925119, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.908571, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.932987, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   26.0s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.836429, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.920165, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.865390, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.872500, total=   0.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.945047, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.922500, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.945455, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.904240, total=   1.1s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.944643, total=   0.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.933571, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.945047, total=   0.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   31.5s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.911429, total=   0.9s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.920833, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.977857, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.900000, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.930556, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.896184, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.955714, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.893214, total=   1.6s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.899188, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   38.7s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.883651, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.955714, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.945455, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.955714, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.883651, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=True, score=0.864583, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.966786, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.831591, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.858036, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.858797, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.789979, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.933571, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   47.3s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.966786, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.873636, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 2), nbc__algorithm=auto, vect__use_idf=False, score=0.843981, total=   1.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.896184, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.932987, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.920165, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.836429, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.861310, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.945047, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.922500, total=   0.9s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.945455, total=   0.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.904240, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   54.4s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.977857, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.925119, total=   1.4s
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.933571, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   0.9s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.899188, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.945047, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.966786, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.921645, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.930556, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.896184, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.966786, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.893214, total=   2.0s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   1.9s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.925119, total=   1.6s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.1min
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.844802, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.920833, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.933571, total=   1.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.909545, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.864583, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.851071, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.858797, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.789979, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.920833, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.921645, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=uniform, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.843981, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.899188, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.933571, total=   1.0s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.2min
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   0.9s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.885952, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.889286, total=   0.9s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.805952, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.955714, total=   0.8s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=True, score=0.920833, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 1), nbc__algorithm=auto, vect__use_idf=False
# ...
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.933571, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.925119, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  2.1min
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.899188, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.945047, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.966786, total=   1.0s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.921645, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer at 0x7f2da1b68950>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.930556, total=   0.7s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.966786, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.893214, total=   1.2s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.896184, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.858797, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.925119, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.883651, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.933571, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.920833, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.877996, total=   1.2s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=True, score=0.909545, total=   1.2s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.955714, total=   1.1s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.851071, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.858797, total=   1.4s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.896184, total=   1.5s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.789979, total=   1.3s
# [CV] vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.922500, total=   1.3s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.921645, total=   1.2s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.873948, total=   1.4s
# [CV]  vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, nbc__weights=distance, vect__ngram_range=(1, 3), nbc__algorithm=auto, vect__use_idf=False, score=0.920833, total=   1.6s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:  2.4min finished
# /home/siddhant/python/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.89795, std: 0.04199, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.94632, std: 0.02678, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.88789, std: 0.04014, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.88005, std: 0.05764, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.90526, std: 0.03450, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.93164, std: 0.02419, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.91093, std: 0.03673, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.88083, std: 0.05537, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.90223, std: 0.03648, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.93187, std: 0.02468, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.90146, std: 0.03576, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.88577, std: 0.04672, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'uniform'},
#  mean: 0.90151, std: 0.04233, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.94743, std: 0.02598, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.89328, std: 0.03665, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.88142, std: 0.05746, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.91060, std: 0.03270, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.93277, std: 0.02439, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.91347, std: 0.03486, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.88229, std: 0.05455, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.90887, std: 0.03505, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.93187, std: 0.02468, params: {'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.90667, std: 0.02970, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'},
#  mean: 0.88868, std: 0.04487, params: {'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f2da1b890d0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3), 'nbc__algorithm': 'auto', 'nbc__weights': 'distance'}]

# %%
print()
print("Best Estimator:")
pp.pprint(grid_search.best_estimator_)
print()
print("Best Parameters:")
pp.pprint(grid_search.best_params_)
print()
print("Used Scorer Function:")
pp.pprint(grid_search.scorer_)
print()
print("Number of Folds:")
pp.pprint(grid_search.n_splits_)
print()
# Out:
# Best Estimator:
# Pipeline(steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#   ...wski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance'))])
#
# Best Parameters:
# {'nbc__algorithm': 'auto',
#  'nbc__weights': 'distance',
#  'vect__ngram_range': (1, 1),
#  'vect__tokenizer': <function stemming_tokenizer at 0x7f2da1b68950>,
#  'vect__use_idf': False}
#
# Used Scorer Function:
# make_scorer(average_precision_score, average=weighted)
#
# Number of Folds:
# 10

# %%
#Let's train the classifier that achieved the best performance,
# considering the select scoring-function,
# on the entire original TRAINING-Set
Y_predicted = grid_search.predict(X_test)

# Evaluate the performance of the classifier on the original Test-Set
output_classification_report = metrics.classification_report(
                                    Y_test,
                                    Y_predicted,
                                    target_names=target_names)
print()
print ("----------------------------------------------------")
print(output_classification_report)
print ("----------------------------------------------------")
print()

# Compute the confusion matrix
confusion_matrix = metrics.confusion_matrix(Y_test, Y_predicted)
print()
print("Confusion Matrix: True-Classes X Predicted-Classes")
print(confusion_matrix)
print()

#Mathews_core coeff,#Normalized accuracy 

metrics.matthews_corrcoef(Y_test,Y_predicted),metrics.accuracy_score(Y_test,Y_predicted)
# Out:
# ----------------------------------------------------
#              precision    recall  f1-score   support
#
#    Positive       0.86      0.97      0.91       308
#    negative       0.96      0.81      0.88       250
#
# avg / total       0.91      0.90      0.90       558
#
# ----------------------------------------------------
#
#
# Confusion Matrix: True-Classes X Predicted-Classes
# [[300   8]
#  [ 48 202]]
# (0.80272589142185058, 0.89964157706093195)

# %% [markdown]
# # Classifier 2

# %%
## Vectorization object
vectorizer_2 = TfidfVectorizer(strip_accents= None,preprocessor = None)

## classifier
from sklearn.svm import SVC
nbc_2 = SVC()

pipeline = Pipeline([('vect',vectorizer_2),('nbc_2',nbc_2),])

parameters = {
    'vect__tokenizer': [stemming_tokenizer,stemming_tokenizer_no_stop_words],
    'vect__ngram_range': [(1, 1), (1, 2),(1,3)],
    'vect__use_idf':[True,False],
    'nbc_2__kernel':['linear', 'poly', 'rbf', 'sigmoid'],
    'nbc_2__probability':[True],
    'nbc_2__shrinking':[True]
    
    }

grid_search_2 = GridSearchCV(pipeline,
                           parameters,
                           scoring=metrics.make_scorer(metrics.average_precision_score, average='weighted'),
                           cv=10,
                           n_jobs=-1,
                           verbose=10)

# %%
grid_fit=grid_search_2.fit(X_train, Y_train)
grid_fit.grid_scores_
# Out:
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.6s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.962963, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=1.000000, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.968929, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.8s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.967273, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988426, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.4s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.950467, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.980769, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.4s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.967273, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988426, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.977857, total=   1.1s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.944643, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.8s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.962963, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.945047, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.980769, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.956364, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988426, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.957024, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.1s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.955714, total=   1.1s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.980769, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.966786, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.980769, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.977857, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.933636, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 1), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988426, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.7s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.962963, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.950467, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.967273, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988426, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.5s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.980769, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   17.1s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.968929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.945534, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988426, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.9s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.944643, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   19.9s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.966786, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.968929, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.977857, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.978182, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.967593, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.945047, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.980769, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.955714, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.966786, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.980769, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.945534, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   24.0s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.977857, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 2), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.976852, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.957024, total=   0.6s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   0.8s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.944643, total=   0.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.962963, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.950467, total=   1.1s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   1.4s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.945534, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.976852, total=   1.2s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.977857, total=   1.2s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   29.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   1.7s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.988929, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.955714, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.980769, total=   1.2s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.968929, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.966786, total=   1.1s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.933636, total=   1.1s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, nbc_2__shrinking=True, score=0.976852, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   1.2s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.957024, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.933571, total=   1.3s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.945047, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.966786, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   36.0s
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.988929, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.966786, total=   0.9s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.955113, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=True, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.956364, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.957024, total=   1.0s
# [CV] nbc_2__kernel=linear, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# ...
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.8s
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.9s
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  2.7min
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.8s
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.9s
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.8s
# [CV] nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.9s
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.727273, total=   0.8s
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.723214, total=   0.8s
# [CV]  nbc_2__kernel=sigmoid, vect__ngram_range=(1, 3), vect__use_idf=False, nbc_2__probability=True, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, nbc_2__shrinking=True, score=0.722222, total=   0.8s
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed:  2.7min finished
# /home/siddhant/python/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.97878, std: 0.01172, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.97871, std: 0.01260, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.97226, std: 0.01744, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.97189, std: 0.01738, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.97470, std: 0.01308, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.97509, std: 0.01288, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.97600, std: 0.01366, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.97074, std: 0.01577, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.96600, std: 0.01586, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.97056, std: 0.01577, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.96480, std: 0.01829, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.97081, std: 0.01195, params: {'nbc_2__kernel': 'linear', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'poly', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'rbf', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 1)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 2)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': True, 'vect__ngram_range': (1, 3)},
#  mean: 0.72352, std: 0.00129, params: {'nbc_2__kernel': 'sigmoid', 'nbc_2__probability': True, 'nbc_2__shrinking': True, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__use_idf': False, 'vect__ngram_range': (1, 3)}]

# %%
print()
print("Best Estimator:")
pp.pprint(grid_search_2.best_estimator_)
print()
print("Best Parameters:")
pp.pprint(grid_search_2.best_params_)
print()
print("Used Scorer Function:")
pp.pprint(grid_search_2.scorer_)
print()
print("Number of Folds:")
pp.pprint(grid_search_2.n_splits_)
print()
# Out:
# Best Estimator:
# Pipeline(steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#   ...',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
#
# Best Parameters:
# {'nbc_2__kernel': 'linear',
#  'nbc_2__probability': True,
#  'nbc_2__shrinking': True,
#  'vect__ngram_range': (1, 1),
#  'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>,
#  'vect__use_idf': True}
#
# Used Scorer Function:
# make_scorer(average_precision_score, average=weighted)
#
# Number of Folds:
# 10

# %%
#Let's train the classifier that achieved the best performance,
# considering the select scoring-function,
# on the entire original TRAINING-Set
Y_predicted = grid_search_2.predict(X_test)

# Evaluate the performance of the classifier on the original Test-Set
output_classification_report = metrics.classification_report(
                                    Y_test,
                                    Y_predicted,
                                    target_names=target_names)
print()
print ("----------------------------------------------------")
print(output_classification_report)
print ("----------------------------------------------------")
print()

# Compute the confusion matrix
confusion_matrix = metrics.confusion_matrix(Y_test, Y_predicted)
print()
print("Confusion Matrix: True-Classes X Predicted-Classes")
print(confusion_matrix)
print()

#Mathews_core coeff,#Normalized accuracy 

metrics.matthews_corrcoef(Y_test,Y_predicted),metrics.accuracy_score(Y_test,Y_predicted)
# Out:
# ----------------------------------------------------
#              precision    recall  f1-score   support
#
#    Positive       0.96      0.98      0.97       308
#    negative       0.97      0.94      0.96       250
#
# avg / total       0.96      0.96      0.96       558
#
# ----------------------------------------------------
#
#
# Confusion Matrix: True-Classes X Predicted-Classes
# [[301   7]
#  [ 14 236]]
# (0.92400679228485771, 0.9623655913978495)

# %% [markdown]
# # Classifier 3

# %%
## Vectorization object
vectorizer_3 = TfidfVectorizer(strip_accents= None,preprocessor = None)

## classifier
from sklearn.ensemble import RandomForestClassifier
nbc_3 = RandomForestClassifier()

pipeline = Pipeline([('vect',vectorizer_3),('nbc_3',nbc_3),])

parameters = {
    'vect__tokenizer': [stemming_tokenizer,stemming_tokenizer_no_stop_words],
    'vect__ngram_range': [(1, 1), (1, 2),(1,3)],
    'vect__use_idf':[True],
    'nbc_3__n_estimators':[10,20],
    'nbc_3__max_features':['sqrt','log2','auto'],
    'nbc_3__bootstrap':[False]
    }

grid_search_3 = GridSearchCV(pipeline,
                           parameters,
                           scoring=metrics.make_scorer(metrics.average_precision_score, average='weighted'),
                           cv=10,
                           n_jobs=-1,
                           verbose=10)

# %%
grid_fit=grid_search_3.fit(X_train, Y_train)
grid_fit.grid_scores_
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.966786, total=   0.4s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.885952, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.977857, total=   0.4s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.932987, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.966786, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.899188, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.945047, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.988929, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.5s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.967273, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.965278, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.889863, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.3s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.957024, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.944643, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.955714, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.912236, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.912236, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.944643, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.893214, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.902778, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    4.2s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.945455, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.912236, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.945047, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.966786, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.933571, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.4s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.883651, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.932987, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.968929, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.944643, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.938182, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.988426, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.829405, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.932987, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.966786, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.872500, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    7.7s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.906786, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.908571, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.911429, total=   0.8s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.945534, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.945047, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.955113, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.906786, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.966786, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.977857, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.0s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.922500, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.988929, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.945047, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.955714, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.945047, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.901818, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.976852, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.851071, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.889863, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.957024, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.844881, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   13.0s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.858797, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.899188, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.944643, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.944643, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.945455, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.875714, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=10, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.921800, total=   0.5s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.988929, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.966786, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.968929, total=   0.4s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.920833, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.955714, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   15.7s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.946429, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=1.000000, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.921645, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 1), score=0.945047, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.937857, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.962963, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.977857, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.920833, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.968929, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.945047, total=   1.2s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.950467, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   19.8s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.966786, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.945455, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.925119, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 1), score=0.955113, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.968929, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.988929, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.920833, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.962963, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.966786, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.932987, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.966786, total=   0.6s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.933636, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 2), score=0.976852, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.906786, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   24.7s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.957024, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.988929, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.883651, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.980769, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.955714, total=   1.1s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.893214, total=   1.1s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.966786, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.933636, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.874193, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 2), score=0.965278, total=   1.1s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.988929, total=   0.7s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.977857, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.883651, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.962963, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   30.9s
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.955714, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.937857, total=   1.0s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.944643, total=   0.8s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.965278, total=   0.9s
# [CV] nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=sqrt, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.909545, total=   1.0s
# ...
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.896184, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.962963, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.966786, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.908571, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.944643, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.921645, total=   0.5s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer at 0x7f8846990ea0>, vect__ngram_range=(1, 3), score=0.965278, total=   0.6s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.889863, total=   0.7s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.899188, total=   0.6s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.966786, total=   0.6s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.908571, total=   0.6s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.893214, total=   0.7s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.912236, total=   0.6s
# [CV] nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3)
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.920833, total=   0.7s
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.932987, total=   0.6s
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.945455, total=   0.5s
# [CV]  nbc_3__max_features=auto, nbc_3__bootstrap=False, vect__use_idf=True, nbc_3__n_estimators=20, vect__tokenizer=<function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, vect__ngram_range=(1, 3), score=0.929894, total=   0.4s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.4min finished
# /home/siddhant/python/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.94952, std: 0.03222, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.92583, std: 0.02493, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.94128, std: 0.02822, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.91723, std: 0.03955, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94872, std: 0.02882, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.90561, std: 0.04085, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)},
#  mean: 0.94887, std: 0.03448, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.95314, std: 0.01599, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.95434, std: 0.02272, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94312, std: 0.03515, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94003, std: 0.03701, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.93662, std: 0.02801, params: {'nbc_3__max_features': 'sqrt', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)},
#  mean: 0.92185, std: 0.03834, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.90442, std: 0.05175, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.92651, std: 0.02725, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.89805, std: 0.04658, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.91602, std: 0.03432, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.88903, std: 0.05625, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)},
#  mean: 0.93292, std: 0.03238, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.92434, std: 0.03993, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.94581, std: 0.02279, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.90454, std: 0.03959, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.93489, std: 0.03425, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.88716, std: 0.03335, params: {'nbc_3__max_features': 'log2', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)},
#  mean: 0.95127, std: 0.02827, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.93493, std: 0.03056, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.94804, std: 0.01157, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.93313, std: 0.02275, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94199, std: 0.02333, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.90324, std: 0.04406, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 10, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)},
#  mean: 0.96010, std: 0.01784, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 1)},
#  mean: 0.94676, std: 0.02620, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 1)},
#  mean: 0.95273, std: 0.02782, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94080, std: 0.02677, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 2)},
#  mean: 0.94334, std: 0.03512, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>, 'vect__ngram_range': (1, 3)},
#  mean: 0.91982, std: 0.02314, params: {'nbc_3__max_features': 'auto', 'nbc_3__bootstrap': False, 'vect__use_idf': True, 'nbc_3__n_estimators': 20, 'vect__tokenizer': <function stemming_tokenizer_no_stop_words at 0x7f8846990f28>, 'vect__ngram_range': (1, 3)}]

# %%
print()
print("Best Estimator:")
pp.pprint(grid_search_3.best_estimator_)
print()
print("Best Parameters:")
pp.pprint(grid_search_3.best_params_)
print()
print("Used Scorer Function:")
pp.pprint(grid_search_3.scorer_)
print()
print("Number of Folds:")
pp.pprint(grid_search_3.n_splits_)
print()
# Out:
# Best Estimator:
# Pipeline(steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#   ...imators=20, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False))])
#
# Best Parameters:
# {'nbc_3__bootstrap': False,
#  'nbc_3__max_features': 'auto',
#  'nbc_3__n_estimators': 20,
#  'vect__ngram_range': (1, 1),
#  'vect__tokenizer': <function stemming_tokenizer at 0x7f8846990ea0>,
#  'vect__use_idf': True}
#
# Used Scorer Function:
# make_scorer(average_precision_score, average=weighted)
#
# Number of Folds:
# 10

# %%
#Let's train the classifier that achieved the best performance,
# considering the select scoring-function,
# on the entire original TRAINING-Set
Y_predicted = grid_search_3.predict(X_test)

# Evaluate the performance of the classifier on the original Test-Set
output_classification_report = metrics.classification_report(
                                    Y_test,
                                    Y_predicted,
                                    target_names=target_names)
print()
print ("----------------------------------------------------")
print(output_classification_report)
print ("----------------------------------------------------")
print()

# Compute the confusion matrix
confusion_matrix = metrics.confusion_matrix(Y_test, Y_predicted)
print()
print("Confusion Matrix: True-Classes X Predicted-Classes")
print(confusion_matrix)
print()

#Mathews_core coeff,#Normalized accuracy 

metrics.matthews_corrcoef(Y_test,Y_predicted),metrics.accuracy_score(Y_test,Y_predicted)
# Out:
# ----------------------------------------------------
#              precision    recall  f1-score   support
#
#    Positive       0.92      0.96      0.94       308
#    negative       0.95      0.89      0.92       250
#
# avg / total       0.93      0.93      0.93       558
#
# ----------------------------------------------------
#
#
# Confusion Matrix: True-Classes X Predicted-Classes
# [[297  11]
#  [ 27 223]]
# (0.86294601463580811, 0.93189964157706096)
